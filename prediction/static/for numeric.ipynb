# %%
import pandas as pd
data1 = pd.read_excel("cleaned_data1.xls")

# %%
data1.head()
# Out:
#       PropertyCity  Veteran  EstimatedCreditScore BankruptcyForeClosureCheck  \
# 15019      Nokomis        1                     3                         no
# 15019      Nokomis        1                     3                         no
# 15019      Nokomis        1                     3                         no
# 15019      Nokomis        1                     3                         no
# 15019      Nokomis        1                     3                         no
#
#          PropertyUse  EstimatedPropertyValue  LoanAmountRequested  \
# 15019  OWNEROCCUPIED                  550000               180001
# 15019  OWNEROCCUPIED                  550000               180001
# 15019  OWNEROCCUPIED                  550000               180001
# 15019  OWNEROCCUPIED                  550000               180001
# 15019  OWNEROCCUPIED                  550000               180001
#
#        AdditionalCashRequired  LenderId  APRPercentage   ...   LoanAmount  \
# ...

# %%
cleanup_nums = {"BankruptcyForeClosureCheck":     {"bankruptcy": 1, "foreclosure": 2, "no": 3},
                "PropertyUse": {"INVESTMENTPROPERTY": 1, "OWNEROCCUPIED": 2, "SECONDHOME": 3}}
data1.replace(cleanup_nums, inplace=True)
data1.head()
# Out:
#       PropertyCity  Veteran  EstimatedCreditScore  BankruptcyForeClosureCheck  \
# 15019      Nokomis        1                     3                           3
# 15019      Nokomis        1                     3                           3
# 15019      Nokomis        1                     3                           3
# 15019      Nokomis        1                     3                           3
# 15019      Nokomis        1                     3                           3
#
#        PropertyUse  EstimatedPropertyValue  LoanAmountRequested  \
# 15019            2                  550000               180001
# 15019            2                  550000               180001
# 15019            2                  550000               180001
# 15019            2                  550000               180001
# 15019            2                  550000               180001
#
#        AdditionalCashRequired  LenderId  APRPercentage   ...   LoanAmount  \
# ...

# %%
a = data1['PropertyCity'].unique()

# %%
j = 1
b = []
for i in a:
    b.append((j,i))
    j=j+1

# %%
b
# Out:
# [(1, 'Nokomis'),
#  (2, 'Alliance'),
#  (3, 'Antioch'),
#  (4, 'Charlotte'),
#  (5, 'Renton'),
#  (6, 'Cypress'),
#  (7, 'Spring Lake'),
#  (8, 'Great Falls'),
#  (9, 'Vero Beach'),
#  (10, 'San Leandro'),
#  (11, 'Hillsboro'),
#  (12, 'Macungie'),
#  (13, 'Panama City'),
#  (14, 'Channahon'),
#  (15, 'Midland Park'),
#  (16, 'Woodford'),
#  (17, 'Jamaica'),
#  (18, 'Richardson'),
#  (19, 'Hockessin'),
#  (20, 'New Bern'),
#  (21, 'Blue Springs'),
#  (22, 'Bokeelia'),
#  (23, 'Burlington Flats'),
#  (24, 'Blairsville'),
#  (25, 'Pasadena'),
#  (26, 'Las Vegas'),
#  (27, 'Owings Mills'),
#  (28, 'Deland'),
#  (29, 'Williamston'),
#  (30, 'Escondido'),
#  (31, 'Marietta'),
#  (32, 'Villa Park'),
#  (33, 'Covington'),
#  (34, 'Lawrenceburg'),
#  (35, 'Cross Junction'),
#  (36, 'East Elmhurst'),
#  (37, 'Huntington Beach'),
#  (38, 'Midland'),
#  (39, 'Ladson'),
#  (40, 'Lawton'),
#  (41, 'Lakeville'),
#  (42, 'Scotts Valley'),
#  (43, 'Conroe'),
#  (44, 'Carmel'),
# ...

# %%
j = 1
c = {}
for i in a:
    c[i] = j
    j = j+1

# %%
c
# Out:
# {'Nokomis': 1,
#  'Alliance': 2,
#  'Antioch': 3,
#  'Charlotte': 4,
#  'Renton': 5,
#  'Cypress': 6,
#  'Spring Lake': 7,
#  'Great Falls': 8,
#  'Vero Beach': 9,
#  'San Leandro': 10,
#  'Hillsboro': 11,
#  'Macungie': 12,
#  'Panama City': 13,
#  'Channahon': 14,
#  'Midland Park': 15,
#  'Woodford': 16,
#  'Jamaica': 17,
#  'Richardson': 18,
#  'Hockessin': 19,
#  'New Bern': 20,
#  'Blue Springs': 21,
#  'Bokeelia': 22,
#  'Burlington Flats': 23,
#  'Blairsville': 24,
#  'Pasadena': 25,
#  'Las Vegas': 26,
#  'Owings Mills': 27,
#  'Deland': 28,
#  'Williamston': 29,
#  'Escondido': 30,
#  'Marietta': 31,
#  'Villa Park': 32,
#  'Covington': 33,
#  'Lawrenceburg': 34,
#  'Cross Junction': 35,
#  'East Elmhurst': 36,
#  'Huntington Beach': 37,
#  'Midland': 38,
#  'Ladson': 39,
#  'Lawton': 40,
#  'Lakeville': 41,
#  'Scotts Valley': 42,
#  'Conroe': 43,
#  'Carmel': 44,
#  'Seven Valleys': 45,
#  'Chapel Hill': 46,
#  'Harriman': 47,
#  'O Fallon': 48,
#  'Lake Jackson': 49,
# ...

# %%
cleanup_num = {"PropertyCity":     c}
data1.replace(cleanup_num, inplace=True)
data1.head()
# Out:
#        PropertyCity  Veteran  EstimatedCreditScore  \
# 15019             1        1                     3
# 15019             1        1                     3
# 15019             1        1                     3
# 15019             1        1                     3
# 15019             1        1                     3
#
#        BankruptcyForeClosureCheck  PropertyUse  EstimatedPropertyValue  \
# 15019                           3            2                  550000
# 15019                           3            2                  550000
# 15019                           3            2                  550000
# 15019                           3            2                  550000
# 15019                           3            2                  550000
#
#        LoanAmountRequested  AdditionalCashRequired  LenderId  APRPercentage  \
# 15019               180001                       0         9          4.656
# ...

# %%
data1.to_excel("numeric_cleaned.xls")
